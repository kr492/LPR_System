# %% [markdown]
# ## 0. Install and Import Dependencies

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Requirement already satisfied: easyocr in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.6.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.21.0)
# Requirement already satisfied: opencv-python-headless in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (4.11.0.86)
# Requirement already satisfied: scipy in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.15.2)
# Requirement already satisfied: numpy in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.2.4)
# Requirement already satisfied: Pillow in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (11.1.0)
# Requirement already satisfied: scikit-image in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.0.7)
# Requirement already satisfied: pyclipper in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: filelock in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: networkx in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (2025.3.13)
# Requirement already satisfied: packaging>=21 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Requirement already satisfied: imutils in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (0.5.4)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\somesh banode\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# ## 1. Read in Image, Grayscale and Blur

# %%
img = cv2.imread('image5.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# ## 2. Apply filter and find edges for localization

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 250, 2) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 3. Find Contours and Apply Mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %% [markdown]
# ### location

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 4. Use Easy OCR To Read Text

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[0, np.int32(3)],
#    [288, np.int32(3)],
#    [288, np.int32(69)],
#    [0, np.int32(69)]],
#   'KA G2MP 9657',
#   np.float64(0.811248459968232))]

# %% [markdown]
# ## 5. Render Result

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
